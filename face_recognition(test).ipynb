# %%
pip install face_recognition

# %%
import face_recognition
import cv2
import numpy as np
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.patheffects as path_effects

# load images from DB
url = 'https://team3-cctv-bucket.s3.us-west-2.amazonaws.com/testingpic1.PNG'
response = requests.get(url)
image2 = Image.open(BytesIO(response.content))
image2 = image2.convert("RGB")
buffer = BytesIO()
image2.save(buffer, format="JPEG")



plt.show(image2)

# %%
# 키오스크에서 입력받을 사진
known_image = face_recognition.load_image_file("/content/drive/MyDrive/python_ML/face/3.jpg")
# DB 에서 따올 얼굴사진
unknown_image = face_recognition.load_image_file("/content/drive/MyDrive/python_ML/face/indi (1).jpg")


# 인코딩부분
# 이미지 자체에서 얼굴을 인식하지 못하면 encoding에서 에러발생!
known_encoding = face_recognition.face_encodings(known_image)[0]
unknown_encoding = face_recognition.face_encodings(unknown_image)[0]

results = face_recognition.compare_faces([known_encoding], unknown_encoding)
print("Is the unknown face a picture of known? {}".format(results[0]))
# print("Is the unknown face a picture of Obama? {}".format(results[1]))
print("Is the unknown face a new person that we've never seen before? {}".format(not True in results))
